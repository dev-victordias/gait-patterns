# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import svm
from sklearn.model_selection import train_test_split

# %%
# generating the hip sensor media files in X, Y and Z
# for all individuals and all attempts
# for this to generate for all individuals,
# we must change the filename in the first loop

tentativa = []

for i in range(1,9):
    try:
        arquivo = 'WBDS01walkT0' + str(i) + 'mkr.txt'
        dados = pd.read_csv(arquivo, sep='\t')
        dados = dados.fillna(0)
        tentativa.append(dados)
    except:
        continue
        
for j in range(0,8):
    try:
        mean_df = tentativa[j].mean()
        print(mean_df['R.ASISX'], mean_df['R.ASISY'], mean_df['R.ASISZ'],
              mean_df['L.ASISX'], mean_df['L.ASISY'], mean_df['L.ASISZ'], 
              mean_df['R.PSISX'], mean_df['R.PSISY'], mean_df['R.PSISZ'],
              mean_df['L.PSISX'],  mean_df['L.PSISY'], mean_df['L.PSISZ'],
              mean_df['R.Iliac.CrestX'], mean_df['R.Iliac.CrestY'], mean_df['R.Iliac.CrestZ'], 
              mean_df['L.Iliac.CrestY'], mean_df['L.Iliac.CrestY'], mean_df['L.Iliac.CrestY'])
    except:
        continue

# the generated output is pasted into an excel sheet (mediasQuadril)
# and later divided by axes (x, y and z)

# %%
sns.set_style('darkgrid')
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
plt.plot(tentativa[1]['Time'], tentativa[1]['R.ASISX'])

# %%
# promising axis due to signal periodicity over time

plt.plot(tentativa[1]['Time'], tentativa[1]['R.ASISY'])

# %%
# promising axis due to signal periodicity over time

plt.plot(tentativa[1]['Time'], tentativa[1]['R.ASISZ'])

# %%
# reading the spreadsheets and preparing the arguments for the SVM algorithm

dados = pd.read_excel('mediasQuadril.xlsx')
dados = dados.dropna()
dados = dados.drop('Indivíduo', 1)
y_ = dados['Classificação']
dados = dados.drop('Classificação', 1)

X = np.array(dados)
y = np.array(y_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.8910891089108911

# %%
# reading the spreadsheets and preparing the arguments for the SVM algorithm

dados = pd.read_excel('mediasX.xlsx')
dados = dados.dropna()
dados = dados.drop('Indivíduo', 1)
y_ = dados['Classificação']
dados = dados.drop('Classificação', 1)

X = np.array(dados)
y = np.array(y_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.7821782178217822

# %%
# reading the spreadsheets and preparing the arguments for the SVM algorithm

dados = pd.read_excel('mediasY.xlsx')
dados = dados.dropna()
dados = dados.drop('Indivíduo', 1)
y_ = dados['Classificação']
dados = dados.drop('Classificação', 1)

X = np.array(dados)
y = np.array(y_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.801980198019802

# %%
# reading the spreadsheets and preparing the arguments for the SVM algorithm

dados = pd.read_excel('mediasZ.xlsx')
dados = dados.dropna()
dados = dados.drop('Indivíduo', 1)
y_ = dados['Classificação']
dados = dados.drop('Classificação', 1)

X = np.array(dados)
y = np.array(y_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.8811881188118812

# %%
# reading the spreadsheets and preparing the arguments for the SVM algorithm

dados = pd.read_excel('mediasQuadrilT05.xlsx')
dados = dados.dropna()
dados = dados.drop('Indivíduo', 1)
y_ = dados['Classificação']
dados = dados.drop('Classificação', 1)

X = np.array(dados)
y = np.array(y_)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.6153846153846154

# %%
from scipy.fftpack import fft
 
def get_fft_values(y_values, T, N, f_s):
    f_values = np.linspace(0.0, 1.0/(2.0*T), N//2)
    fft_values_ = np.fft.fft(y_values)
    fft_values = 2.0/N * np.abs(fft_values_[0:N//2])
    return f_values, fft_values
 
t_n = 10
N = 4498
T = t_n / N
f_s = 1/T
 
f_values, fft_values = get_fft_values(np.sin(T), T, N, f_s)
 
plt.plot(f_values, fft_values.real, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]', fontsize=16)
plt.ylabel('Amplitude', fontsize=16)
plt.title("Frequency domain of the signal", fontsize=16)
plt.show()

# %%
x_ = np.array(tentativa[0]['R.ASISX'])
y_ = np.array(tentativa[0]['R.ASISY'])
z_ = np.array(tentativa[0]['R.ASISZ'])

# %%
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})

# %%
from scipy.fftpack import fft
 
def get_fft_values(y_values, T, N, f_s):
    f_values = np.linspace(0.0, 1.0/(2.0*T), N//2)
    fft_values_ = fft(y_values)
    fft_values = 2.0/N * np.abs(fft_values_[0:N//2])
    return f_values, fft_values

# %%
# FFT 'R.ASISX'

t_n = 10
N = 4500
T = t_n / N
f_s = 1/T
 
f_values, fft_values = get_fft_values(x_, T, N, f_s)
 
plt.plot(f_values, fft_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]', fontsize=16)
plt.ylabel('Amplitude', fontsize=16)
plt.title("Frequency domain of the signal", fontsize=16)
plt.show()

# %%
# FFT 'R.ASISY'

t_n = 10
N = 4500
T = t_n / N
f_s = 1/T
 
f_values, fft_values = get_fft_values(y_, T, N, f_s)
 
plt.plot(f_values, fft_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]', fontsize=16)
plt.ylabel('Amplitude', fontsize=16)
plt.title("Frequency domain of the signal", fontsize=16)
plt.show()

# %%
# FFT 'R.ASISZ'

t_n = 10
N = 4500
T = t_n / N
f_s = 1/T
 
f_values, fft_values = get_fft_values(z_, T, N, f_s)
 
plt.plot(f_values, fft_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]', fontsize=16)
plt.ylabel('Amplitude', fontsize=16)
plt.title("Frequency domain of the signal", fontsize=16)
plt.show()

# %%
from scipy.signal import welch
 
def get_psd_values(y_values, T, N, f_s):
    f_values, psd_values = welch(y_values, fs=f_s)
    return f_values, psd_values

# %%
# PSD 'R.ASISX'

t_n = 10
N = 1000
T = t_n / N
f_s = 1/T
 
f_values, psd_values = get_psd_values(x_, T, N, f_s)
 
plt.plot(f_values, psd_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]')
plt.ylabel('PSD [V**2 / Hz]')
plt.show()

# %%
# PSD 'R.ASISY'

t_n = 10
N = 1000
T = t_n / N
f_s = 1/T
 
f_values, psd_values = get_psd_values(y_, T, N, f_s)
 
plt.plot(f_values, psd_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]')
plt.ylabel('PSD [V**2 / Hz]')
plt.show()

# %%
# PSD 'R.ASISZ'

t_n = 10
N = 1000
T = t_n / N
f_s = 1/T
 
f_values, psd_values = get_psd_values(z_, T, N, f_s)
 
plt.plot(f_values, psd_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]')
plt.ylabel('PSD [V**2 / Hz]')
plt.show()

# %%
from scipy.signal import find_peaks

# %%
peaks, _ = find_peaks(x_, height=1, width=1)
print(peaks)
plt.plot(x_)
plt.plot(peaks, x_[peaks], "x")
plt.plot(np.zeros_like(x_), "--", color="gray")
plt.show()
# Out:
# [  18   99  163  283  371  409  550  686  818  902  950 1072 1194 1200
#  1343 1482 1607 1734 1863 1949 2016 2031 2134 2217 2255 2393 2467 2523
#  2648 2804 2939 3033 3193 3328 3356 3397 3485 3488 3615 3684 3752 3825
#  3884 4019 4152 4205 4285 4411]

# %%
peaks, _ = find_peaks(y_, height=1, width=1)
print(peaks)
plt.plot(y_)
plt.plot(peaks, y_[peaks], "x")
plt.plot(np.zeros_like(y_), "--", color="gray")
plt.show()
# Out:
# [   8   22   55  164  167  172  196  281  308  335  414  449  547  574
#   600  644  692  696  726  817  842  913  993 1066 1084 1087 1120 1211
#  1244 1247 1348 1374 1385 1486 1490 1523 1608 1635 1738 1771 1864 1868
#  1895 1898 2049 2134 2160 2163 2259 2290 2393 2411 2422 2565 2587 2653
#  2655 2685 2691 2806 2811 2841 2941 2954 2966 3051 3087 3108 3206 3235
#  3241 3328 3344 3381 3397 3464 3481 3488 3505 3507 3656 3754 3774 3784
#  3794 3889 3930 4029 4047 4053 4121 4148 4183 4201 4269 4281 4303 4317
#  4416 4451 4456]

# %%
peaks, _ = find_peaks(z_, height=1, width=1)
print(peaks)
plt.plot(z_)
plt.plot(peaks, z_[peaks], "x")
plt.plot(np.zeros_like(z_), "--", color="gray")
plt.show()
# Out:
# [  81   83   98  102  328  336  355  620  721  739  747  881 1012 1131
#  1134 1247 1421 1424 1438 1532 1536 1545 1547 1654 1658 1675 1944 1949
#  1957 2181 2206 2436 2459 2575 2577 2587 2742 2748 2762 2869 2962 2967
#  2972 3091 3284 3297 3330 3530 3552 3555 3681 3687 3807 3810 3828 3934
#  3941 3956 4072 4092 4191 4194 4215 4310 4312 4329 4354 4466]
